# %%
import math

rakuten = []
au_TsukaihoudaiMAX5G4G = []
au_PitattoPlan = []
sb_MerihariMuseigen = []
sb_MiniFitPlan = []
docomo_5GgigahoPremier = []
docomo_5GgigaLight = []
docomo_gigahoPremier = []
docomo_gigaLight = []
ahamo = []
povo = []
linemo_miniPlan = []
linemo_smartphonePlan = []
uq_KurikoshiS = []
uq_KurikoshiM = []
uq_KurikoshiL = []
uq_KurikoshiSZouryo = []
uq_KurikoshiMZouryo = []
uq_KurikoshiLZouryo = []
ymobile_simpleS = []
ymobile_simpleM = []
ymobile_simpleL = []
ymobile_simpleSZouryo = []
ymobile_simpleMZouryo = []
ymobile_simpleLZouryo = []



gbLimit = 65
bigPrice = 99999

for i in range(gbLimit):
	if i < 1:
		rakuten.append(1078)
		au_TsukaihoudaiMAX5G4G.append(3278)
		au_PitattoPlan.append(3465)
		sb_MerihariMuseigen.append(5588)
		sb_MiniFitPlan.append(3278)
		docomo_5GgigahoPremier.append(5665)
		docomo_5GgigaLight.append(3465)
		docomo_gigahoPremier.append(5555)
		docomo_gigaLight.append(3465)
		ahamo.append(2970)
		povo.append(2728)
		linemo_miniPlan.append(990)
		linemo_smartphonePlan.append(2728)
		uq_KurikoshiS.append(1628)
		uq_KurikoshiM.append(2728)
		uq_KurikoshiL.append(3828)
		uq_KurikoshiSZouryo.append(2178)
		uq_KurikoshiMZouryo.append(3278)
		uq_KurikoshiLZouryo.append(4378)
		ymobile_simpleS.append(2178)
		ymobile_simpleM.append(3278)
		ymobile_simpleL.append(4158)
		ymobile_simpleSZouryo.append(2728)
		ymobile_simpleMZouryo.append(3828)
		ymobile_simpleLZouryo.append(4708)

	elif i < 2:
		rakuten.append(1078)
		au_TsukaihoudaiMAX5G4G.append(3278)
		au_PitattoPlan.append(5115)
		sb_MerihariMuseigen.append(5588)
		sb_MiniFitPlan.append(4378)
		docomo_5GgigahoPremier.append(5665)
		docomo_5GgigaLight.append(4565)
		docomo_gigahoPremier.append(5555)
		docomo_gigaLight.append(4565)
		ahamo.append(2970)
		povo.append(2728)
		linemo_miniPlan.append(990)
		linemo_smartphonePlan.append(2728)
		uq_KurikoshiS.append(1628)
		uq_KurikoshiM.append(2728)
		uq_KurikoshiL.append(3828)
		uq_KurikoshiSZouryo.append(2178)
		uq_KurikoshiMZouryo.append(3278)
		uq_KurikoshiLZouryo.append(4378)
		ymobile_simpleS.append(2178)
		ymobile_simpleM.append(3278)
		ymobile_simpleL.append(4158)
		ymobile_simpleSZouryo.append(2728)
		ymobile_simpleMZouryo.append(3828)
		ymobile_simpleLZouryo.append(4708)
	elif i < 3:
		rakuten.append(1078)
		au_TsukaihoudaiMAX5G4G.append(3278)
		au_PitattoPlan.append(5115)
		sb_MerihariMuseigen.append(5588)
		sb_MiniFitPlan.append(5478)
		docomo_5GgigahoPremier.append(5665)
		docomo_5GgigaLight.append(4565)
		docomo_gigahoPremier.append(5555)
		docomo_gigaLight.append(4565)
		ahamo.append(2970)
		povo.append(2728)
		linemo_miniPlan.append(990)
		linemo_smartphonePlan.append(2728)
		uq_KurikoshiS.append(1628)
		uq_KurikoshiM.append(2728)
		uq_KurikoshiL.append(3828)
		uq_KurikoshiSZouryo.append(2178)
		uq_KurikoshiMZouryo.append(3278)
		uq_KurikoshiLZouryo.append(4378)
		ymobile_simpleS.append(2178)
		ymobile_simpleM.append(3278)
		ymobile_simpleL.append(4158)
		ymobile_simpleSZouryo.append(2728)
		ymobile_simpleMZouryo.append(3828)
		ymobile_simpleLZouryo.append(4708)
	elif i < 4:
		rakuten.append(2178)
		au_TsukaihoudaiMAX5G4G.append(7236)
		au_PitattoPlan.append(5115)
		sb_MerihariMuseigen.append(7238)
		sb_MiniFitPlan.append(5478+(i-2)*1100)
		docomo_5GgigahoPremier.append(7315)
		docomo_5GgigaLight.append(5665)
		docomo_gigahoPremier.append(7205)
		docomo_gigaLight.append(5665)
		ahamo.append(2970)
		povo.append(2728)
		linemo_miniPlan.append(990+550*(i-2))
		linemo_smartphonePlan.append(2728)
		uq_KurikoshiS.append(1628+1100*(i-2))
		uq_KurikoshiM.append(2728)
		uq_KurikoshiL.append(3828)
		uq_KurikoshiSZouryo.append(2178)
		uq_KurikoshiMZouryo.append(3278)
		uq_KurikoshiLZouryo.append(4378)
		ymobile_simpleS.append(2178+1100*(i-2))
		ymobile_simpleM.append(3278)
		ymobile_simpleL.append(4158)
		ymobile_simpleSZouryo.append(2728)
		ymobile_simpleMZouryo.append(3828)
		ymobile_simpleLZouryo.append(4708)
	elif i < 5:
		rakuten.append(2178)
		au_TsukaihoudaiMAX5G4G.append(7236)
		au_PitattoPlan.append(6765)
		sb_MerihariMuseigen.append(7238)
		sb_MiniFitPlan.append(5478+(i-2)*1100)
		docomo_5GgigahoPremier.append(7315)
		docomo_5GgigaLight.append(5665)
		docomo_gigahoPremier.append(7205)
		docomo_gigaLight.append(5665)
		ahamo.append(2970)
		povo.append(2728)
		linemo_miniPlan.append(990+550*(i-2))
		linemo_smartphonePlan.append(2728)
		uq_KurikoshiS.append(1628+1100*(i-2))
		uq_KurikoshiM.append(2728)
		uq_KurikoshiL.append(3828)
		uq_KurikoshiSZouryo.append(2178)
		uq_KurikoshiMZouryo.append(3278)
		uq_KurikoshiLZouryo.append(4378)
		ymobile_simpleS.append(2178+1100*(i-2))
		ymobile_simpleM.append(3278)
		ymobile_simpleL.append(4158)
		ymobile_simpleSZouryo.append(2728)
		ymobile_simpleMZouryo.append(3828)
		ymobile_simpleLZouryo.append(4708)
	elif i < 6:
		rakuten.append(2178)
		au_TsukaihoudaiMAX5G4G.append(7236)
		au_PitattoPlan.append(6765)
		sb_MerihariMuseigen.append(7238)
		sb_MiniFitPlan.append(5478+(i-2)*1100)
		docomo_5GgigahoPremier.append(7315)
		docomo_5GgigaLight.append(5665)
		docomo_gigahoPremier.append(7205)
		docomo_gigaLight.append(5665)
		ahamo.append(2970)
		povo.append(2728)
		linemo_miniPlan.append(990+550*(i-2))
		linemo_smartphonePlan.append(2728)
		uq_KurikoshiS.append(1628+1100*(i-2))
		uq_KurikoshiM.append(2728)
		uq_KurikoshiL.append(3828)
		uq_KurikoshiSZouryo.append(2178+1100*(i-4))
		uq_KurikoshiMZouryo.append(3278)
		uq_KurikoshiLZouryo.append(4378)
		ymobile_simpleS.append(2178+1100*(i-2))
		ymobile_simpleM.append(3278)
		ymobile_simpleL.append(4158)
		ymobile_simpleSZouryo.append(2728+1100*(i-4))
		ymobile_simpleMZouryo.append(3828)
		ymobile_simpleLZouryo.append(4708)


	elif i < 7:
		rakuten.append(2178)
		au_TsukaihoudaiMAX5G4G.append(7236)
		au_PitattoPlan.append(6765)
		sb_MerihariMuseigen.append(7238)
		sb_MiniFitPlan.append(5478+(i-2)*1100)
		docomo_5GgigahoPremier.append(7315)
		docomo_5GgigaLight.append(6765)
		docomo_gigahoPremier.append(7205)
		docomo_gigaLight.append(6765)
		ahamo.append(2970)
		povo.append(2728)
		linemo_miniPlan.append(990+550*(i-2))
		linemo_smartphonePlan.append(2728)
		uq_KurikoshiS.append(1628+1100*(i-2))
		uq_KurikoshiM.append(2728)
		uq_KurikoshiL.append(3828)
		uq_KurikoshiSZouryo.append(2178+1100*(i-4))
		uq_KurikoshiMZouryo.append(3278)
		uq_KurikoshiLZouryo.append(4378)
		ymobile_simpleS.append(2178+1100*(i-2))
		ymobile_simpleM.append(3278)
		ymobile_simpleL.append(4158)
		ymobile_simpleSZouryo.append(2728+1100*(i-4))
		ymobile_simpleMZouryo.append(3828)
		ymobile_simpleLZouryo.append(4708)

	elif i < 15:
		rakuten.append(2178)
		au_TsukaihoudaiMAX5G4G.append(7236)
		au_PitattoPlan.append(6765)
		sb_MerihariMuseigen.append(7238)
		sb_MiniFitPlan.append(5478+(i-2)*1100)
		docomo_5GgigahoPremier.append(7315)
		docomo_5GgigaLight.append(6765)
		docomo_gigahoPremier.append(7205)
		docomo_gigaLight.append(6765)
		ahamo.append(2970)
		povo.append(2728)
		linemo_miniPlan.append(990+550*(i-2))
		linemo_smartphonePlan.append(2728)
		uq_KurikoshiS.append(1628+1100*(i-2))
		uq_KurikoshiM.append(2728)
		uq_KurikoshiL.append(3828)
		uq_KurikoshiSZouryo.append(2178+1100*(i-4))
		uq_KurikoshiMZouryo.append(3278)
		uq_KurikoshiLZouryo.append(4378)
		ymobile_simpleS.append(2178+1100*(i-2))
		ymobile_simpleM.append(3278)
		ymobile_simpleL.append(4158)
		ymobile_simpleSZouryo.append(2728+1100*(i-4))
		ymobile_simpleMZouryo.append(3828)
		ymobile_simpleLZouryo.append(4708)

	elif i < 20:
		rakuten.append(2178)
		au_TsukaihoudaiMAX5G4G.append(7236)
		au_PitattoPlan.append(6765+(i-6)*1100)
		sb_MerihariMuseigen.append(7238)
		sb_MiniFitPlan.append(5478+(i-2)*1100)
		docomo_5GgigahoPremier.append(7315)
		docomo_5GgigaLight.append(6765+1100*(i-6))
		docomo_gigahoPremier.append(7205)
		docomo_gigaLight.append(6765+(i-6)*1100)
		ahamo.append(2970)
		povo.append(2728)
		linemo_miniPlan.append(990+550*(i-2))
		linemo_smartphonePlan.append(2728)
		uq_KurikoshiS.append(1628+1100*(i-2))
		uq_KurikoshiM.append(2728+1100*(i-14))
		uq_KurikoshiL.append(3828)
		uq_KurikoshiSZouryo.append(2178+1100*(i-4))
		uq_KurikoshiMZouryo.append(3278)
		uq_KurikoshiLZouryo.append(4378)
		ymobile_simpleS.append(2178+1100*(i-2))
		ymobile_simpleM.append(3278+1100*(i-14))
		ymobile_simpleL.append(4158)
		ymobile_simpleSZouryo.append(2728+1100*(i-4))
		ymobile_simpleMZouryo.append(3828)
		ymobile_simpleLZouryo.append(4708)

	elif i < 25:
		rakuten.append(3278)
		au_TsukaihoudaiMAX5G4G.append(7236)
		au_PitattoPlan.append(6765+(i-6)*1100)
		sb_MerihariMuseigen.append(7238)
		sb_MiniFitPlan.append(5478+(i-2)*1100)
		docomo_5GgigahoPremier.append(7315)
		docomo_5GgigaLight.append(6765+1100*(i-6))
		docomo_gigahoPremier.append(7205)
		docomo_gigaLight.append(6765+(i-6)*1100)
		ahamo.append(2970+550*(i-19))
		povo.append(2728+550*(i-19))
		linemo_miniPlan.append(990+550*(i-2))
		linemo_smartphonePlan.append(2728+550*(i-19))
		uq_KurikoshiS.append(1628+1100*(i-2))
		uq_KurikoshiM.append(2728+1100*(i-15))
		uq_KurikoshiL.append(3828)
		uq_KurikoshiSZouryo.append(2178+1100*(i-4))
		uq_KurikoshiMZouryo.append(3278+1100*(i-19))
		uq_KurikoshiLZouryo.append(4378)
		ymobile_simpleS.append(2178+1100*(i-2))
		ymobile_simpleM.append(3278+1100*(i-15))
		ymobile_simpleL.append(4158)
		ymobile_simpleSZouryo.append(2728+1100*(i-4))
		ymobile_simpleMZouryo.append(3828+1100*(i-19))
		ymobile_simpleLZouryo.append(4708)

	elif i < 30:
		rakuten.append(3278)
		au_TsukaihoudaiMAX5G4G.append(7236)
		au_PitattoPlan.append(6765+(i-6)*1100)
		sb_MerihariMuseigen.append(7238)
		sb_MiniFitPlan.append(5478+(i-2)*1100)
		docomo_5GgigahoPremier.append(7315)
		docomo_5GgigaLight.append(6765+1100*(i-6))
		docomo_gigahoPremier.append(7205)
		docomo_gigaLight.append(6765+(i-6)*1100)
		ahamo.append(2970+550*(i-19))
		povo.append(2728+550*(i-19))
		linemo_miniPlan.append(990+550*(i-2))
		linemo_smartphonePlan.append(2728+550*(i-19))
		uq_KurikoshiS.append(1628+1100*(i-2))
		uq_KurikoshiM.append(2728+1100*(i-15))
		uq_KurikoshiL.append(3828+1100*(i-24))
		uq_KurikoshiSZouryo.append(2178+1100*(i-4))
		uq_KurikoshiMZouryo.append(3278+1100*(i-19))
		uq_KurikoshiLZouryo.append(4378)
		ymobile_simpleS.append(2178+1100*(i-2))
		ymobile_simpleM.append(3278+1100*(i-15))
		ymobile_simpleL.append(4158+1100*(i-24))
		ymobile_simpleSZouryo.append(2728+1100*(i-4))
		ymobile_simpleMZouryo.append(3828+1100*(i-19))
		ymobile_simpleLZouryo.append(4708)

	elif i < 60:
		rakuten.append(3278)
		au_TsukaihoudaiMAX5G4G.append(7236+(i-29)*1100)
		au_PitattoPlan.append(6765+(i-6)*1100)
		sb_MerihariMuseigen.append(7238)
		sb_MiniFitPlan.append(5478+(i-2)*1100)
		docomo_5GgigahoPremier.append(7315)
		docomo_5GgigaLight.append(6765+1100*(i-6))
		docomo_gigahoPremier.append(7205)
		docomo_gigaLight.append(6765+(i-6)*1100)
		ahamo.append(2970+550*(i-19))
		povo.append(2728+550*(i-19))
		linemo_miniPlan.append(990+550*(i-2))
		linemo_smartphonePlan.append(2728+550*(i-19))
		uq_KurikoshiS.append(1628+1100*(i-2))
		uq_KurikoshiM.append(2728+1100*(i-15))
		uq_KurikoshiL.append(3828+1100*(i-24))
		uq_KurikoshiSZouryo.append(2178+1100*(i-4))
		uq_KurikoshiMZouryo.append(3278+1100*(i-19))
		uq_KurikoshiLZouryo.append(4378+1100*(i-29))
		ymobile_simpleS.append(2178+1100*(i-2))
		ymobile_simpleM.append(3278+1100*(i-15))
		ymobile_simpleL.append(4158+1100*(i-24))
		ymobile_simpleSZouryo.append(2728+1100*(i-4))
		ymobile_simpleMZouryo.append(3828+1100*(i-19))
		ymobile_simpleLZouryo.append(4708+1100*(i-29))

	else:
		rakuten.append(3278)
		au_TsukaihoudaiMAX5G4G.append(7236+(i-29)*1100)
		au_PitattoPlan.append(6765+(i-6)*1100)
		sb_MerihariMuseigen.append(7238)
		sb_MiniFitPlan.append(5478+(i-2)*1100)
		docomo_5GgigahoPremier.append(7315)
		docomo_5GgigaLight.append(6765+1100*(i-6))
		docomo_gigahoPremier.append(7205+1100*(i-59))
		docomo_gigaLight.append(6765+(i-6)*1100)
		ahamo.append(2970+550*(i-19))
		povo.append(2728+550*(i-19))
		linemo_miniPlan.append(990+550*(i-2))
		linemo_smartphonePlan.append(2728+550*(i-19))
		uq_KurikoshiS.append(1628+1100*(i-2))
		uq_KurikoshiM.append(2728+1100*(i-15))
		uq_KurikoshiL.append(3828+1100*(i-24))
		uq_KurikoshiSZouryo.append(2178+1100*(i-4))
		uq_KurikoshiMZouryo.append(3278+1100*(i-19))
		uq_KurikoshiLZouryo.append(4378+1100*(i-29))
		ymobile_simpleS.append(2178+1100*(i-2))
		ymobile_simpleM.append(3278+1100*(i-15))
		ymobile_simpleL.append(4158+1100*(i-24))
		ymobile_simpleSZouryo.append(2728+1100*(i-4))
		ymobile_simpleMZouryo.append(3828+1100*(i-19))
		ymobile_simpleLZouryo.append(4708+1100*(i-29))

# %%
planIndex = ("rakuten", "au_TsukaihoudaiMAX5G4G", "au_PitattoPlan", "sb_MerihariMuseigen", "sb_MiniFitPlan", "docomo_5GgigahoPremier",
             "docomo_5GgigaLight", "docomo_gigahoPremier", "docomo_gigaLight", "ahamo", "povo", "linemo_miniPlan", "linemo_smartphonePlan", "uq_KurikoshiS", "uq_KurikoshiM", "uq_KurikoshiL", "uq_KurikoshiSZouryo", "uq_KurikoshiMZouryo", "uq_KurikoshiLZouryo", "ymobile_simpleS", "ymobile_simpleM", "ymobile_simpleL", "ymobile_simpleSZouryo", "ymobile_simpleMZouryo", "ymobile_simpleLZouryo")

orderedPricePlanPareList = []
orderedPlanList = []
gbList = []

for i in range(gbLimit):
	tmpTapple = (rakuten[i], au_TsukaihoudaiMAX5G4G[i], au_PitattoPlan[i], sb_MerihariMuseigen[i], sb_MiniFitPlan[i], docomo_5GgigahoPremier[i], docomo_5GgigaLight[i], docomo_gigahoPremier[i], docomo_gigaLight[i], ahamo[i], povo[i], linemo_miniPlan[i], linemo_smartphonePlan[i], uq_KurikoshiS[i], uq_KurikoshiM[i], uq_KurikoshiL[i], uq_KurikoshiSZouryo[i], uq_KurikoshiMZouryo[i], uq_KurikoshiLZouryo[i], ymobile_simpleS[i], ymobile_simpleM[i], ymobile_simpleL[i], ymobile_simpleSZouryo[i], ymobile_simpleMZouryo[i], ymobile_simpleLZouryo[i])
	orderedPricePlanPare = sorted(zip(tmpTapple, planIndex))
	orderedPricePlanPareList.append(orderedPricePlanPare)
	orderedPlan = []
	for j in range(len(orderedPricePlanPare)):
		orderedPlan.append(orderedPricePlanPare[j][1])
	orderedPlanList.append(orderedPlan)
	gbList.append(i+1)

orderedPricePlanPareinGB = list(zip(gbList, orderedPlanList))

# print(orderedPricePlanPareList)
# print(orderedPricePlanPareinGB)

separator = []
separatedorderedPricecPlanPareinGB = []

for i in range(len(orderedPlanList)-1):
	if (orderedPlanList[i][0] != orderedPlanList[i+1][0] or orderedPlanList[i][1] != orderedPlanList[i+1][1] or orderedPlanList[i][2] != orderedPlanList[i+1][2] or orderedPlanList[i][3] != orderedPlanList[i+1][3] or orderedPlanList[i][4] != orderedPlanList[i+1][4] or orderedPlanList[i][5] != orderedPlanList[i+1][5]):
		separator.append(i)
# print(separator)

for i in range(len(separator)):
	if (i==len(separator)-1):
		separatedorderedPricecPlanPareinGB.append(orderedPricePlanPareinGB[separator[i]])
		separatedorderedPricecPlanPareinGB.append(orderedPricePlanPareinGB[separator[i]+1])
	else:
		separatedorderedPricecPlanPareinGB.append(orderedPricePlanPareinGB[separator[i]])

		
# print(orderedPricePlanPareinGB)
# print(separatedorderedPricecPlanPareinGB)

gbSelections = []

for i in range(len(separator)):
	if (i==0):
		gbSelections.append(str(separator[i]+1)+'GB 以下')
	elif (i==len(separator)-1):
		gbSelections.append(str(separator[i-1]+1)+'GB 〜 '+str(separator[i]+1)+'GB')
		gbSelections.append(str(separator[i]+1)+'GB 以上')
	else:
		gbSelections.append(str(separator[i-1]+1)+'GB 〜 '+str(separator[i]+1)+'GB')

print(gbSelections)

# %%
noOption = 0
au1 = {'5min': 770, 'noLimit': 1870}
docomo = {'5min': 770, 'noLimit': 1870}
sb = {'5min': 880, 'noLimit': 1980}
au2 = {'5min': 880, 'noLimit': 1980}
linemo = {'5min': 550, 'noLimit': 1650}
povo = {'5min': 550, 'noLimit': 1650}
ahamo = {'5min': 0, 'noLimit': 1100}
rakuten = {'10min': 1100}


print("１ヶ月間の合計通話時間: ")
callDuration = int(input())
print("通話時間5分超過分の１ヶ月間の合計（Exp. 7分、10分30秒、8分の通話が一回ずつあった場合、それぞれから5分引いた時間の合計値 = 2分 + 5分30秒 + 3分 = 10分30秒 を入力して下さい。）: ")
fiveSurplus = int(input())
print("通話時間10分超過分の１ヶ月間の合計（Exp. 9分、20分、17分の通話が一回ずつあった場合、それぞれから10分引いた時間の合計値 = 0分 +　10分 + 7分 = 17分 を入力して下さい。）: ")
tenSurplus = int(input())


au1_calc = {'noOption': math.ceil(callDuration/30)*22, '5min': 770+math.ceil(fiveSurplus/30)*22, 'noLimit': 1870}
docomo_calc = {'noOption': math.ceil(callDuration/30)*22, '5min': 770+math.ceil(fiveSurplus/30)*22, 'noLimit': 1870}
sb_calc = {'noOption': math.ceil(callDuration/30)*22, '5min': 880+math.ceil(fiveSurplus/30)*22, 'noLimit': 1980}
au2_calc = {'noOption': math.ceil(callDuration/30)*22, '5min': 880+math.ceil(fiveSurplus/30)*22, 'noLimit': 1980}
linemo_calc = {'noOption': math.ceil(callDuration/30)*22, '5min': 550+math.ceil(fiveSurplus/30)*22, 'noLimit': 1650}
povo_calc = {'noOption': math.ceil(callDuration/30)*22, '5min': 550+math.ceil(fiveSurplus/30)*22, 'noLimit': 1650}
ahamo_calc = {'5min': math.ceil(fiveSurplus/30)*22, 'noLimit': 1100}
rakuten_calc = {'noOption': math.ceil(callDuration/30)*22, '10min': 1100+math.ceil(tenSurplus/30)*22}

# print(au1_calc)

au1_sorted = sorted(au1_calc.items(), key=lambda x: x[1])
docomo_sorted = sorted(docomo_calc.items(), key=lambda x: x[1])
sb_sorted = sorted(sb_calc.items(), key=lambda x: x[1])
au2_sorted = sorted(au2_calc.items(), key=lambda x: x[1])
linemo_sorted = sorted(linemo_calc.items(), key=lambda x: x[1])
povo_sorted = sorted(povo_calc.items(), key=lambda x: x[1])
ahamo_sorted = sorted(ahamo_calc.items(), key=lambda x: x[1])
rakuten_sorted = sorted(rakuten_calc.items(), key=lambda x: x[1])

# print(au1_sorted)

# %%
#internet

softbankAir 
softbankHikari = {
	'building': 1100,
	'base': {'todate': 5720, 'shugo': 4180},
	'HissuOption': 550
}
